# %%
import numpy as np
import pandas as pd
import openpyxl as opx

# %% [markdown]
# Desarrollo del diseño de vigas según la E.060

# %%
#Definimos la geometría de la sección de concreto:
b = float(input("Ingrese ancho de viga (cm): "))
h = float(input("Ingrese peralte de viga (cm): "))
print(f"Ancho de viga: {b} cm, Peralte de viga: {h} cm")
# Out:
# Ancho de viga: 30.0 cm, Peralte de viga: 60.0 cm

# %%
#Definimos las propiedades de los materiales:
fc = float(input("Ingrese resistencia a la compresión del concreto (kgf/cm2): "))
fy = float(input("Ingrese esfuerzo de fluencia del acero de refuerzo (kgf/cm2): "))
print(f"f'c = {fc} kgf/cm2, fy = {fc} kgf/cm2")
# Out:
# f'c = 210.0 kgf/cm2, fy = 210.0 kgf/cm2

# %%
#Creación del bloque de Witney "a = b1*c"
esfuerzo_eq = 0.85*fc #kgf/cm2
"a=b1*c" #a viene a ser la dimensión paralela al peralte del bloque en compresión
#Debemos de calcular b1 y c.
#Cálculo de b1

print(esfuerzo_eq)
# Out:
# 178.5

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Cálculo del As requerido
